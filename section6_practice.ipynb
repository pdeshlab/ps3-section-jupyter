# %% [markdown]
# ## Practice: Standard Errors, P-values, T-statistics, and Bias vs. Noise
#
# In this actvity, we'll practice interpreting output from `difference_in_means()` using the `ToothGrowth` dataset. This is a built-in R dataset from a study on the effect of Vitamin C on tooth growth in guinea pigs.
#
# Here is what each column means:
#
# - **len**: Tooth length (the outcome variable)
# - **supp**: Supplement type — either `"OJ"` (orange juice) or `"VC"` (ascorbic acid/Vitamin C)
# - **dose**: Dose of Vitamin C in milligrams per day (0.5, 1, or 2)
#
# We will treat **supplement type** as our treatment variable and compare **OJ vs. VC** to see if the delivery method affects tooth growth.

# %% [markdown]
# ## Part 1: Loading the Data
#
# Run the cell below to load the packages you'll need for the exercise and to load in the dataset.

# %%
# Run this cell, don't change anything about it 
library(estimatr)

data <- ToothGrowth
head(data)
# Out:
#   len  supp dose
# 1  4.2 VC   0.5
# 2 11.5 VC   0.5
# 3  7.3 VC   0.5
# 4  5.8 VC   0.5
# 5  6.4 VC   0.5
# 6 10.0 VC   0.5

# %% [markdown]
# Take a look at the different types of supplements given to guinea pigs.

# %%
table_sup <- table(data$supp)
table_sup
# Out:
# OJ VC
# 30 30

# %% [markdown]
# ## Part 2: Data Analysis
#
# **Question 1.** Use the `difference_in_means()` function to estimate the effect of supplement type on tooth length, comparing "VC" as the baseline condition to "OJ". Store the results in supp_effect and print it.

# %%
# Estimate the treatment effect using difference_in_means()
supp.effect <- difference_in_means(..., 
                                   data = data, 
                                   condition1 = '...', 
                                   condition2 = '...')
supp.effect

# %% [markdown]
# **Question 2.** What part of the outcome is the standard error? Print it below.

# %%
std_error <- '...'
std_error

# %% [markdown]
# **Question 3.** Which of the following statements about the **standard error** you identified above is **NOT** correct?
#
# - **a**: The standard error captures how much the estimate might vary from the true effect due to random chance.
# - **b**: If we had recruited more guinea pigs into this study, we would expect the standard error to decrease.
# - **c**: A larger standard error means the experiment is more biased. A perfectly unbiased experiment would have a standard error of zero.
# - **d**: If the estimated effect is small relative to the standard error, we cannot be very confident that the true effect is different from zero.
#
# Replace the `'...'` below with your answer letter.

# %%
# Put your answer where the ... is below. Leave the quotes.
q3.answer <- '...'

# %% [markdown]
# **Question 4.** What part of the output is the p-value? Print it below.

# %%
# Copy the p-value below
p.value <- ...
p.value

# %% [markdown]
# **Question 5.** Using the p-value you found in Question 4 and an alpha level of **0.05**, which of the following is the correct interpretation?
#
# - **a**: We reject the null hypothesis. The difference in tooth length between OJ and VC groups is statistically significant at the 5% level.
# - **b**: We fail to reject the null hypothesis. The p-value is below alpha, meaning the result could easily be due to chance.
# - **c**: We reject the null hypothesis. The p-value being above 0.05 tells us the result is definitely caused by the supplement type.
# - **d**: We fail to reject the null hypothesis. The p-value is above alpha, meaning we do not have enough evidence to conclude the supplement type has an effect.
#
# Replace the `'...'` below with your answer letter.

# %%
# Put your answer where the ... is below. Leave the quotes.
q5.answer <- '...'

# %% [markdown]
# **Question 6.** A classmate looks at your results and says: *"The estimated effect of OJ vs. VC is positive, so this experiment proves that OJ always causes more tooth growth than VC."*
#
# Replace `...` below with `TRUE` if the experiment proves OJ always causes more tooth growth, or `FALSE` if it does not.

# %%
experiment.proves.OJ.always.better <- ...

# EXPLAIN YOUR REASONING IN THE COMMENTS HERE:
# YOUR REASONING GOES HERE (1-2 SENTENCES).
